# %% [markdown]
# # Analyst Command Center - Preliminary Data Exploration
#
# This notebook demonstrates standard data exploration techniques used to clean, validate, and understand the core dataset before it gets injected into the Streamlit app.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load synthetic dataset (or replace with real CSV)
try:
    df = pd.read_csv('../data/processed/synthetic_financials.csv')
    print("Data loaded successfully. Shape:", df.shape)
except FileNotFoundError:
    print("File not found. Try running the Streamlit app first to generate synthetic data.")
